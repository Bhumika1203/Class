# %%
# Ques.1 Write code to position 5 equal-sized (50 X 50px) boxes A, B, C, D, and E as followsC
1 box A 200px from the left, and 200px from the top of the viewport
2 box B -30px left, and -30px above from the center of box A
3 box B -30px right, and -30px above from the center of box A
4 box B -30px left, and -30px below from the center of box A
5 box B -30px right, and -30px below from the center of box A.


Ans. <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        .box{
            height: 50px;
            width: 50px;
            border: 2px solid rgb(197, 113, 113);
            font-size: 30px;
            text-align: center;

        }
    </style>
</head>
<body >
   <div >
    <div class="box" style="position: fixed;left: 200px; top: 200px;background-color: pink;">A </div>
    <div class="box" style="position: fixed; left: 170px; top: 170px; background-color: thistle;">B</div>
    <div class="box" style="position: fixed; left: 230px;top: 170px; background-color: lightsteelblue">C</div>
    <div class="box" style="position: fixed;left: 170px;top: 230px;background-color: burlywood; ">D</div>
    <div class="box" style="position: fixed; left: 230px;top: 230px;background-color: lightgreen;">E</div>
   </div>
</body>
</html>



#Q.2  Explain the difference between Absolute and Relative positioning.

Ans. Absolute positioning is a CSS positioning method where an element is removed from the normal document flow and is positioned relative to the nearest positioned ancestor
Absolute positioning is a CSS positioning method where an element is removed from the normal document flow and is positioned relative to the nearest positioned ancestor viewport.



Relative positioning is a CSS positioning method where an element is positioned relative to its normal position in the document flow. The element remains in the document flow, and its space is still preserved, but it can be offset using
top, left, right and bottom prperty.


#Q.3 Create a card as shown in the picture below. (You can use CSS float property only for layout)


Ans.<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <div style="border: 2px solid black; margin: 20px; padding: 40px;">
        <img style="float: right;" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQB4sYLadZlYBjysS4PHq5-8p-EQHj9qeYxxQ&s" alt="Nature image">
        <h2>The Earth!!!</h2>
        <p>
            Nature is Earth's masterpiece a symthony of life composed though millenia .its
            landscape whisper tales of ancient mountains , winding rivers and flourshing forest , reminding us of the planet's boundless beauty. From delicates petals to
            towering redwoods natures's artistry stirs awe and reconnect us to the essence of
            existance .Nature is earth masterpiece a symphony of life composed through
            millennia. Its landscape whisper tales of ancient mountains, winding rivers and
            flourshing forest.
        </p>
    </div>
</body>
</html>


#Ques.4 Create a simple header that sticks to the top of a webpage upon scrolling.??


Ans.  <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        .property{
            border: 3px solid;


        }
        .coloring{
            background-color: black;
            display: flex;

            padding: 20px;


        }
        .logo{
            text-align: left;
            color: white;

        }
        .navbar{
            margin-left: auto;
            display: flex;
            gap: 20px;





        }
       .navbar :hover{
            color: gray;
        }
        .styling{
            border: 1px solid yellow ;
            border-radius: 10px;
            color: yellow;
            background-color: black;
            padding: 10px;
        }
    </style>
</head>
<body class="property">
  <nav class="coloring">
    <div class="logo"><b>Logo</b></div>
    <div class="navbar">
        <a href="#">Home</a>
        <a href="#">Pricing</a>
        <a href="#">Contact</a>
        <a href="#">Term and condition</a>
       <button class="styling">Get started</button>
    </div>
  </nav>
 <div style="overflow: scroll;">
     <p>
    Lorem ipsum dolor sit amet consectectur adipisicing elat .Ipsum possimus modi magni delnati rerum provident minima nist delectus inventore
    facere corrupti reprehenderi magnam ipsa . Earum tempore adipisci repellendus minima! Lorem Ipsum Dolor Sit amet consectur adipisicing elementis
    Lorem ipsum dolor sit amet consectectur adipisicing elat .Ipsum possimus modi magni delnati rerum provident minima nist delectus inventore
    facere corrupti reprehenderi magnam ipsa . Earum tempore adipisci repellendus minima! Lorem Ipsum Dolor Sit amet consectur adipisicing elementis

  </p>
  <h2>Heading 2</h2>
  <p>    Lorem ipsum dolor sit amet consectectur adipisicing elat .Ipsum possimus modi magni delnati rerum provident minima nist delectus inventore
    facere corrupti reprehenderi magnam ipsa . Earum tempore adipisci repellendus minima! Lorem Ipsum Dolor Sit amet consectur adipisicing elementis
    Lorem ipsum dolor sit amet consectectur adipisicing elat .Ipsum possimus modi magni delnati rerum provident minima nist delectus inventore
    facere corrupti reprehenderi magnam ipsa . Earum tempore adipisci repellendus minima! Lorem Ipsum Dolor Sit amet consectur adipisicing elementis
</p>
<h2>Heading 3</h2>
<p>
       Lorem ipsum dolor sit amet consectectur adipisicing elat .Ipsum possimus modi magni delnati rerum provident minima nist delectus inventore
    facere corrupti reprehenderi magnam ipsa . Earum tempore adipisci repellendus minima! Lorem Ipsum Dolor Sit amet consectur adipisicing elementis
    Lorem ipsum dolor sit amet consectectur adipisicing elat .Ipsum possimus modi magni delnati rerum provident minima nist delectus inventore
    facere corrupti reprehenderi magnam ipsa . Earum tempore adipisci repellendus minima! Lorem Ipsum Dolor Sit amet consectur adipisicing elementis

</p>


 </div>
</body>
</html>


#Ques.5 Explain the z-index, with a code example??

Ans. The z-index is a CSS property that controls which element appears on top when elements overlap.
 A higher z-index means the element will be in front of those with a lower value.

 Its Example:

 <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
 <style>
    .box{
        height: 200px;
        width: 200px;
        position: absolute;
    }
    .red{
        left: 50px;
        top: 50px;
        background-color: red;
        z-index: 1;


    }
    .blue{
        left: 100px;
        top: 100px;
        background-color: blue;
        z-index: -2;
    }
    .yellow{
        left: 150px;
        top: 150px;
        background-color: yellow;
        z-index: 3;
    }
 </style>
<body>
    <div class="box red"></div>
    <div class="box blue"></div>
    <div class="box yellow"></div>
</body>
</html>
