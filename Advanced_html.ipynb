# %%
#Ques.1:  List out the features of HTML5?

Answer:   <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <p>HTML5 have many powerful features and improvements over previous versions of HTML. Here are the key features of HTML5:</p>
    <ol type="number">
        <li>
            <h1>New semantic element</h1>
        <p>This element give better structure and meaning to web page.</p>
    </li>
    <ul type="disc">
        <li> article, section</li>
        <li>header , footer</li>
    </ul>
    <li><h1>Multimedia support</h1></li>
    <p>Built in support for media without plugins.</p>
    <ul type="disc">
        <li>video</li>
        <li>audio</li>
    </ul>
    <li><h1>Graphic and animation</h1></li>
    <p>Support for drawing and animation.</p>
    <ul type="disc">
        <li>SVG</li>
        <li>Canvas</li>
    </ul>
    <li><h1>Form enhancement</h1></li>
    <p>Improved form controls.</p>
    <ul type="disc">
        <li>New input type</li>
        <li>New attributes</li>
    </ul>
    <li><h1>Offline and storage support</h1></li>
    <p>Allow work application to work offline.</p>
    <ul type="disc">
    <li>Local storage </li>
    <li>Session storage</li>
    </ul>
    </ol>
</body>
</html>


#Ques.2:   What are HTML Entities? List out 5 commonly used HTML entities?

Answer:    <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <p>An HTML entity is a special piece of text used to represent characters that have a reserved meaning in HTML, or characters that are not easily typed using a keyboard.</p>
    <h2>Some HTML entities;</h2>
    <ol>
        <li>&gt gt <!--It is used for greater than--> </li>
        <li>&lt lt  <!--it is used for less than--></li>
        <li>&nbsp nbsp <!--it is used for non breaking space--></li>
        <li>&amp amp <!-- it is used for ampersand--></li>
        <li>&quot quot <!-- it is used for double quotation mark--></li>
        <li>&copy copyright <!--it is used for copyright--></li>
        <li>&registration <!it is used for resgistration</li>
    </ol>
</body>
</html>


#Ques.3  :Define accessibility in the context of web development. Discuss why it's essential to create accessible
websites and how it benefits different user group?

Answer:   <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
   <p>Accessibility in HTML means making web content usable for everyone desiging web content so that it can be used for everyone including with disablites. HTML provides several features and best practices to improve Accessibility. Ensure equal access to information.</p>
   <p><b>It is essential to create Accesible website for which everyone can use it easily.  </b></p>
    <h2><u>Its Benifits:</u></h2>
    <ol>
        <li>Screen reader support , semantic html. alt text</li>
        <li>Caption , transcript</li>
        <li>Clear layout, keyboard navigation</li>
    </ol>





</body>
</html>


#Ques.4  :List any 3 ways which help us in improving the accessibility of HTML?

Answer  :<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <header>
        <h1>features of HTML:</h1>
        <ol>
            <li><h3><mark>New semantic element</mark</h3></li>
            <p>using new semantice element we easily understand the content of web page. </p>
            <p>some semantic elementis:</p>
            <ul type="disc">
                <li>header</li>
                <li>footer</li>
                <li>main</li>
                <li>nav</li>
            </ul>
            <li><h3><mark>Multimedia support</mark></h3></li>
            <p>Built in support in media</p>
            <ul type="disc">
                <li>image</li>
                <li>video</li>
            </ul>
            <li><h3><mark>Graphic and animation</mark></h3></li>
            <p>Support for drawing and animation</p>
            <ul type="disc">
                <li>canvas</li>
                <li>SVG</li>
            </ul>
            <li><h3><mark>Offline and storage support</mark></h3></li>
            <p>Allow application to work offline</p>
            <ul type="disc">
                <li>Local storage</li>
                <li>Session storage</li>
            </ul>
        </ol>
    </header>
</body>
</html>


#Ques.5  Create a simple web page which has a table. The table must have 2 columns HTML and HTML5. The table
should include a minimum of three rows describing the differences between HTML and HTML5?

Answer:  <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <table border="1" cellspacing="10" cellpadding="10">
        <tr>
            <th>HTML</th>
            <th>HTML:5</th>
        </tr>
        <tr><ul type="disc">
            <td><li>HTML is a old version</li></td>
            <td><li>HTML:5 is a new version</li></td>
        </ul></tr>
        <tr><ul type="disc">
            <td><li>For audio and video HTML required flash and plugins</li></td>
            <td><li>for audio and video HTML:5 doesn't require plugins it required only <mark>audio and video tag</mark></li></td>

        </ul></tr>
        <tr><ul type-dics>
            <td><li>In HTML Graphics is not supported</li></td>
            <td>In HTML:5 graphic is supported by using canvas, SVG</td>
        </ul></tr>
        <tr><ul type="disc">
            <td><li>HTML have limited semantic tag</li></td>
            <td><li>HTML:5 have rich semantic tag like - header, footer,main,nav</li></td>
        </ul></tr>
        <tr><ul type="disc">
            <td><li>Javascript and API are limited</li></td>
            <td><li>HTML:5 have new API</li></td>
        </ul></tr>
    </table>
</body>
</html>
