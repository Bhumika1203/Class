# %%
#Ques.1 : Create a simple page with some div tags and show different ways to add CSS as well as what happens
when you target the same elements with inline, internal, and external CSS. Also, utilize comments in the
project where required

Ans.    : <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>CSS types</title>
    <link rel="stylesheet" href="Assignment.css">
    <style>
        .content{
            color: blue;
            background-color: rgb(216, 150, 99);
            text-decoration: underline;
            font-size: 20px;
            border: 2px;
            margin: 10px;
            padding: 20px;

        }
    </style>
</head>
<body>
     <h1 id="type">CSS types</h1>
    <div class="content">

        <p>There are three ways in which we can apply the CSS.</p>
        <ol>
            <li>Inline CSS</li>
            <li>Internal CSS</li>
            <li>External CSS</li>
        </ol>
    </div> <hr color="black">
    <div style="color: rgb(207, 81, 102); background-color: rgb(80, 78, 82); text-transform: capitalize; border: 2px; margin: 10px; padding: 20px;">
        <ul>
            <li>We apply the inline Css in HTML element</li>
            <li>we apply internal CSS in our head tag using the styling tag</li>
            <li>And we apply the external Css in seprate file than link into the main html file</li> <!--Mainly we use the external CSS.-->
        </ul>
    </div>
</body>
</html>

CSS Linked file


#type{
    text-align: center;
    text-decoration: underline;
    color: white;
    background-color: gray ; height: 50%;
    font-size: 40px;
    border: 2px;
    margin: 10px;
    padding: 20px;


}



Ques.2:    Develope an HTML form with various input elements. Use CSS to style the form, including setting
background colors for input fields. Create a custom color palette for the form elements, and demonstrate
how to apply opacity to one of the form sections.


Ans. :     <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>bhumika</title>
</head>
<body style="background-color: peachpuff;">
    <h1 style="color : rgb(52, 166, 204);">
        <i><u>Welcome to codehelp</u></i>
    </h1>
    <h2 style="color: rgba(231, 12, 67 , 0.5)">
        <i><u>Contact us form</u></i>
    </h2>
    <form>
        Name : <input type="text" placeholder="name"><br>
        Email : <input type="email" placeholder="email"><br>
        Contact number : <input type="number" placeholder="contact no."><br>
        Gender : <input type="radio" placeholder="Gender">male
                 <input type="radio" placeholder="Gender">female
                 <input type="radio" placeholder="Gender">Transgender <br>
        Date of birth : <input type="date" placeholder="dd mm yyyy"><br>
        Rating : <input type="radio" placeholder="Rating">1
                 <input type="radio" placeholder="Rating">2
                 <input type="radio" placeholder="Rating">3 <br>
        Enter your message : <br>
         <input type="text" placeholder="type your message"> <br><br>
         <input type="submit"> <input type="reset">


    </form>

</body>
</html>


Ques.3 :   Build an HTML page with multiple paragraphs, each assigned a unique class name. Write CSS rules using
class selectors to apply distinct styling to each paragraph. Follow the BEM naming convention and
explain how you've named the classes=


Ans.   :    <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        #main {
            text-align: center; color: red; background-color: lightskyblue;
        }
        .first {
            color: rgb(175, 96, 118);background-color: lightgray; line-height: 25px;border: 2px; margin: 10px; padding: 10px;
        }
        .second {
            color: rgb(207, 203, 101);background-color: lightcoral; line-height: 25px;border: 2px; margin: 10px; padding: 10px;
        }
        .third {
            color: rgb(41, 96, 118);background-color: rgb(226, 216, 226);line-height: 25px; border: 2px; margin: 10px; padding: 10px;

        }
        .fourth {
            color: rgba(50, 172, 157, 0.6);background-color: rgba(219, 210, 111, 0.6);line-height: 25px;border: 2px;margin: 10px;padding: 10px;
        }
        .fifth{
            color: rgb(206, 116, 226);background-color: rgb(111, 116, 111);line-height: 25px;border: 2px;margin: 10px;padding: 10px;
        }
    </style>
</head>
<body style="background-color: antiquewhite;">
    <h1 id="main"><i><u>Background in CSS</u></i> </h1> <hr color="black">
    <div>
         <h2 style="color: rgb(196, 100, 100);"><u>Background color</u></h2>
        <P class="first">

            we can set the background color of an element. and use color name like , hex value, RGB,RGBA,HSL,HSLA

        </P>
         <h2 style="color:rgb(129, 90, 165);"><u>Background image</u></h2>
        <P class="second">

            Sets an image as the background. and URL specifies the path to the image file.
        </P>
             <h2 style="color: rgb(124, 146, 81);"><u>Background repeat</u></h2>

        <P class="third">

            It control the repeatability of the background image repeats.Options include repeat, repeat-x, repeat-y, no-repeat.Example: background-repeat: no-repeat;
            Prevents the image from repeating.

        </P>
        <h2 style="color: rgb(142, 60, 218);"><u> background-attachment</u></h2>

        <P class="fourth">

             It Controls the scroll behavior of the background.Options include scroll, fixed, local.
            Example: background-attachment: fixed;
        </P>
         <h2 style="color: rgb(194, 132, 87);"><u>Background position</u></h2>
        <P class="fifth">

            Sets the starting position of the background image.Common values include left, center, right, top, bottom.
            Example: background-position: center;
        </P>
    </div>

</body>
</html>
