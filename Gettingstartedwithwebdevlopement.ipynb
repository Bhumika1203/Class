# %%
#Ques.1  : Explain the basic structure of an HTML page. Why is it important to follow
this structure?

Answer   : The basic structure of an HTML web page is :
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=
    , initial-scale=1.0">
    <title>Document</title>
</head>
<body>


* In this the <!DOCTYPE html> describe the document and version of HTML (like HTML5).
* <HTML lang> describe the root element.
* <Head> describe the meta information about the document.
* <body> display the content.

#Ques.2  : You’re building a small personal profile page. Which HTML tags will you
use to highlight your name as a heading, describe yourself in a paragraph, and
emphasize a key skill?

Answer   : <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=
    , initial-scale=1.0">
    <title>Document</title>
</head>
<body>

    <h1>Bhumika Sharma</h1>
    <p>I am a motivated and curious individual with a background in engineering and a passion for continuous learning. Currently working in the manufacturing industry, I focus on improving safety and efficiency through training programs like KYT (Kiken Yochi Training). I'm also exploring the world of web devlopment, aiming to integrate smart solutions into real-world problems.</p>
     <h3>Key skills:</h3>
     <ol>
        <li>Problem solving and critical thinking</li>
        <li>Communication & Motivation </li>
        <li>Technical skills </li>
        <li>Team  Collaboration</li>
     </ol>


    </body>
</html>

#Ques.3  : Look at the code below. Can you find and fix the mistake?
<!-- This is an HTML comment
<h1>Welcome to my website</h1>

Answer   : yes.
<!-- This is an HTML comment..........In this code the closing tag is missing.

#Ques.4   : You’re creating a form that asks the user to enter their name, select their
country from a list, and click a button to submit. Write the HTML code for this.

Answer    : “Sorry for the inconvenience, But i dont understand it.

#Ques.5   : : Write short HTML code to show your favorite fruits in a bulleted list and
your top 3 programming languages in a numbered list.

Answer    : <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h2>Favourite fruits:</h2>
    <ul Type="bulleted">
        <li>Grapes</li>
        <li>Papaya</li>
        <li>Watermelon</li>
        <li>Mango</li>
        <li>Apple</li>
    </ul>
    <h2>Top 3 Programming language:</h2>
    <ol>
        <li>C language</li>
        <li>Python</li>
        <li> Javascript</li>
    </ol>
</body>
</html>
