# %%
#Ques.1  Build a simple webpage that displays text as shown in the below image?

Answer.  <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <b>This text will be bolded</b><br>
    <i>This text will be italic</i><br>
    <ins>This text will be underlined</ins><br>
    <Mark>This text will be highlighted</Mark><br>
    <div>This is normal text <sup>this is superscripted  </sup>  this is normal again</div>
    <div>This is normal text<sub>this is subscripted</sub></div>
    <div>this is normal text <small> this is small text</small></div>
    <del>This will be deleted</del>
    </body>
</html>


#Ques.2  Build a simple webpage that helps users navigate different web development-related websites. Note: On
clicking the hyperlink the web pages should open in a new tab. Below is a reference image.

Answer.  <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <br><a href="https://pwskills.com" target="blank"> pw skills</a>
    <br><a href="https://MDNdocs.com" target="blank"> MDN docs</a>
    <br><a href="https://pwskillslab.com" target="blank"> pw skills lab</a>
 </body>
</html>

#Ques.3  Create an ordered list of HTML tags. Each list item must include the tag name and some information about
the tag?

Answer.  <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <ol type="number">
        <li><p>Paragraph tag</p></li>
        The paragraph tag in HTML is used to define a paragraph of text.

        <li><h1>heading tag</h1></li>
        heading tags are used to define headings for content. the range of heading tag is h1 to h6 in which h1 is the most important and h6 is the least important.

        <li>break tag</li><br>
        Break tag is used for change the line.

        <li>Anchor tag</li>
        Anchor tag is used for create a hyperlink with the use of anchor tag we move to one link to another and the attribute which is used in anchor tag is href.

        <li><b>bold tag</b></li>
        bold tag is used for bold the content of our text.

        <li><i>italic tag</i></li>
        italic tag is used to display text in italics

        <li><ins>underline tag</ins></li>
        this tag is used for underline the text

        <li><mark>mark tag</mark></li>
        this tag is used for highlight the important text of our content.

        <li><small>small tag</small></li>
        it is used for small our text to the normal text.

       <li><big>big tag</big></li>
       it is used for big the text for the normal text.

       <li>super <sup>script</sup></li>
       this tag is used for slightly above the line.

       <li>sub <sub>script</sub></li>
       this tag is used for below the line

       <li><del>delete tag</del></li>
       It is often used to show that a section of content has been removed

       <li>table tag</li>
       it is used for create a table in our content.


</body>
</html>

#Ques.4  Build a complex nested list structure representing a multi-level table of contents. Use unordered lists
(<ul>) and list items (<li>) with inline-block styling to create a structured layout. Apply formatting tags to
enhance the presentation of list items.

Answer.  <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h1>Table of content</h1>
    <ul>
        <li><ins>Part 1: Introduction</ins></li>
        <li><ins>Part 2: Getting started</ins></li>
        <ul type="circle">
            <li><ins>2.1 Installing the software </ins></li>
            <li><ins>2.2 Creating a new project</ins></li>
            <ul type="Square">
                <li><ins>Project template</ins></li>
                <li><ins>Customizing Settings</ins></li>
            </ul>
            <li>2.3 Exploring the interface</li>
            <ul>
                <li><ins>2.3.1 Toolbae features</ins></li>
                <li><ins>2.3.2 Panel layout</ins></li>
                <ul type="square">
                    <li><ins>2.3.2.1 Docking panel</ins></li>
                    <li><ins>2.3.2.2 Tabbed Interface</ins></li>
                </ul>
            </ul>

        </ul>
        <li><ins>Advanced topics</ins></li>
        <ul type="circle">
            <li><ins>Working with plugins</ins></li>
            <ul type="square">
                <li><ins>3.1.1 Installing the plugins</ins></li>
                <li><ins>3.1.2 Plugins configuration</ins></li>
            </ul>
        </ul>
        <ul>
            <li><ins>Customizing the UI</ins></li>
            <ul>
                <li><ins>3.2.1 Changing the themes</ins></li>
                <li><ins>Configuring Shortcut</ins></li>

            </ul>
        </ul>
        <ul>
            <li><ins>Optimizing Performance</ins></li>
            <ul>
                <li><ins>Caching Startegies</ins></li>
                <li><ins>3.3.2 Resouce minifiction</ins></li>
            </ul>
        </ul>

    </ul>
    <ul>
        <li><ins>Conclusion</ins></li>
    </ul>
</body>
</html>

#Ques.5  Create a table to display a conference schedule. Each row corresponds to a time slot, and each column
corresponds to a room. Some time slots might have multiple sessions running simultaneously in different
rooms. Utilize rowspan and colspan attributes as necessary to accommodate this complex schedule.
(use table attribute “cellpadding”  to give extra padding in each table cell ).

Answer.  <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h1>Conference Schedule</h1>
    <table border="1" Cellpadding="20" cellspacing="10">
        <tr>
            <th>Time</th>
            <th>Room 1</th>
            <th>Room 2</th>
            <th>Room 3</th>
            <th>Room 4</th>
        </tr>
        <tr>
            <td rowspan="3">9:00 AM - 10:00 AM</td>
            <td rowspan="2">Keynote</td>
            <td>Session A</td>
            <td>Session B</td>
            <td rowspan="3">Session C</td>
        </tr>
        <tr>
            <td>Session D</td>
            <td>Session E</td>

        </tr>
        <tr>

            <td>10:30 AM-11:30 AM</td>
            <td>Session F</td>
            <td></td>

        </tr>
        <tr>
            <td>12:00 PM - 1:00 PM</td>
            <td colspan="4">Lunch break</td>
        </tr>
        <tr>
            <td rowspan="2">1:00 PM - 2:00 PM</td>
            <td>Session G</td>
            <td rowspan="2">Session H</td>
            <td>Session I</td>
            <td>Session J</td>
        </tr>
        <tr>
            <td>Session K</td>
            <td>Session L</td>
            <td>Session M</td>
        </tr>


    </table>
</body>
</html>

#Ques. 6  Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech
stack, create a table that lists the tech stack name, its primary use cases, and some key features or
benefits. Below is a reference image.

Answer.   <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <ol type="number">
        <li><h1>HTML</h1></li>
    </ol>
    <table border="2" cellspacing="5" cellpadding="5">
        <tr>
            <th>Primary uses</th>
            <th>Key features/Benifits</th>
        </tr>
        <tr>
            <td rowspan="4">Building the structure of web page</td>
        </tr>
        <tr>
            <td><ul type="circle">
                <li>Simple and easy to learn <br>
                </li>
                <li>Compatible to all web browsers <br></li>
                <li>Allows for semantic markup</li>
            </ul></td>
        </tr>




    </table>
    <ol type="number" start="2" >
        <li><h1>CSS</h1></li>
    </ol>
    <table border="2" cellspacing="5" cellpadding="5">
        <th>Primary uses</th>
        <th>Key feature/Benifits</th>
        <tr>
            <td rowspan="3">Styling and layout of web page</td>
       <tr>
        <td><ul type="circle">
            <li>Allows for seperation of content and presentation <br></li>
            <li>Enables responsive design <br></li>
            <li>Offers a wide range of styling option</li>
        </ul></td>
       </tr>
    </table>
    <ol type="number" start="3">
        <li><h1>Javascript</h1></li>
    </ol>
    <table border="2" cellspacing="5" cellpadding="5">
        <th>Primary uses</th>
        <th>Key features/Benifits</th>
        <tr>
            <td rowspan="3">Making website interactive</td>
        </tr>
        <tr>
            <td><ul type="circle">
                <li>
                    No installation needed — it works right in your web browser.

                    </li>
                    <li>Makes web pages interactive without needing extra plugins.</li>
            </ul></td>
        </tr>
    </table>
</body>
</html>

#Ques.7  Create a description list of full stack web development tech stack, using the <dl> tag. Each term should be
a tech stack name and each description should be a brief explanation of what the tech stack is used for?


Answer.  <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <dl>
        <dt><b>Tech stack</b></dt>
        <dd>Build websites, apps, or software systems and Decide what technologies work best together</dd>
        <dt><b>Frontend</b></dt>
        <dd>fronted is clinet side in frontnend we can prepare the whole UI and add some logic in it <br>in UI we can see Layout,Colors,and typography </dd>
        <dt><b>Backend</b></dt>
        <dd>Backend is our server side  It’s the part that users don’t see, but it powers everything that happens behind the scenes</dd>
    </dl>
    <dl>
        <dt><b>Server</b></dt>
        <dd>server is that where website is hosted</dd>
        <dt><b>Database</b></dt>
        <dd>database be like , where data is stored</dd>
        <dt><b>API</b></dt>
        <dd>API stand for Application programming interface</dd>
        <dt><b>Programming langauge</b></dt>
        <dd>Python : Python is  used for building the back-end (server-side) of web applications.</dd>
        <dd>Javascript :  Javascript is widely used in frontend for makes web pages interactive. </dd>
        <dt><b>html</b></dt>
        <dd>It is used for making the structure of web page</dd>
        <dt><b>CSS</b></dt>
        <dd>It is used to adding the beauty in HTML structure,like <br> color, Fonts,padding,margin,width,height,animation,transition effect</dd>
        <dt><B>Javascript</B></dt>
        <dd>It is used to make website more interactive and dynamic</dd>

    </dl>
    <dl>
        <dt><b>Libraries of frontend</b></dt>
        <dd><ol type="number" start="1">
            <li>React.js</li>
            <li>Chart.js</li>
            <li>Bootstarp</li>
        </ol></dd>
        <dt><b>Libraries of back-end</b></dt>
        <dd><ol type="number" start="1">
            <li>Express.js</li>
            <li>MongoDB</li>
            <li>Node.js</li>
        </ol></dd>
    </dl>



</body>
</html>

#Ques.8 Build a simple blog web page with 3 pages home, web development, and web design. Each page must
contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.
For the home page you can add some information about yourself?

Answer. <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
   <header>
    <h1>home page</h1>
    <p>Hi, I'm Bhumika, and I'm currently learning the exciting world of web development and web design. While I'm still in the early stages of my journey, I'm passionate about exploring new technologies, creating websites, and understanding the principles behind good web design. This blog will document my learning experiences, the challenges I face, and the skills I acquire along the way. I hope you join me on this journey and find something helpful, whether you're also a beginner or just curious about the web development process!</p>
   </header>
   <header>
    <h1>Web devlopement</h1>
    <p>Web development refers to the process of building, designing, and maintaining websites or web applications that run on the internet <ol type="number">
        <li>frontend</li>
        <li>backend</li>
    </ol></p>

   </header>
   <header>
    <h1>Web design</h1>
    <p>Web design is the process of planning, creating, and arranging the visual elements and layout of a website. <ol type="number">
        <li>layout</li>
        <li>color and scheme</li>
        <li>image and graphics</li>
        <li>typography</li>
    </ol></p>
   </header>
</body>
</html>
