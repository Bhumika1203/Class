# %%
#Ques.1   Describe the main differences between the CSS Flexbox layout model and the CSS Grid layout model?

Ans.    Flexbox Layout Model:
Flexbox is a one-dimensional layout system in CSS, which means it is mainly used to arrange items in a single row or a single column.
 It is perfect when you want to distribute space between items and align them properly either horizontally or vertically.
  Flexbox makes it easy to adjust the size of items, wrap them when needed, and align them in the center or at the edges of the container.
   It works best for smaller layout sections like navigation bars, toolbars, or aligning elements inside a card.

       Grid Layout Model:
   CSS Grid is a two-dimensional layout system, which allows you to design layouts in both rows and columns at the same time.
    It is ideal for creating entire web page layouts or complex components with both vertical and horizontal structure.
     Grid gives you more control over spacing, alignment, and the positioning of elements within a grid of cells.
      You can define areas of the page, overlap elements, and create responsive designs easily with Grid, making it powerful for larger and more detailed layouts.


#Ques.2   Explain the role of the following key properties in the Flexbox layout mode?
1. justify-content
2. align-item
3. gap
4. flex-direction
 5. flex-wrap

 Ans. Justify content :  This property help us to align and distribute element across the main axis.

 Align element: This property control the alignment of the flex line when there is extra space in the cross axis.

 Gap : This property is used to maintain the gap between the element if require.

 Flex direction: The property specify the direction of the flex item inside the flex container.
 there are mainly four types of direction
 a. Row
 b. Column
 c. row reverse
 d. column reverse

 Flex Wrap: This property follow flex item to wrap in multiple lines.


 #Ques.3    rite the code to center a div using CSS Flexbox.

      Reference Image given below

Ans.   <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        .box{
            height: 300px;
            width: 300px;
            background-color: lawngreen;
            margin: 100px;


        }
        body{
            display: flex;
            justify-content: center;
            justify-items: center;

        }
    </style>
</head>
<body>
    <div class="box">


    </div>
</body>
</html>


#Q.4  A client of yours wants to add a pricing section on their website to showcase their newly introduced
premium plans.

You have to build the pricing section for their business.


Ans. <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <link rel="stylesheet" href="clon.css">
</head>
<body>
    <section class="three">
        <div class="free">
            <h2 >Free plan</h2>
            <p>For personal</p>
            <h2>$0</h2>
            <ul class="one">
                <li>
                   ✔️1 users
                </li>
                <li>
                    ✔️4 Web mails
                </li>
                <li>
                    ✔️Responsive website
                </li>
                <li>
                    ✔️Free SSL
                </li>
            </ul>
            <button class="styling">Subscribe now</button>
        </div>
        <div class="basic">
            <h2>Basic Plan</h2>
            <p>For small business</p>
            <h2>$29</h2>
            <ul class="four">
                <li>✔️4 Users</li>
                <li>✔️10 Web mails</li>
                <li>✔️Responsive Website</li>
                <li>✔️Free SSL</li>

                <button id="style">Subscribe now</button>
            </ul>
        </div>
        <div class="pro">
            <h2>Pro Plan</h2>
            <p>For enterprise</p>
            <h2>$49</h2>
            <ul class="six">
                <li>✔️Unlimited Users</li>
                <li>✔️Unlimited web users</li>
                <li>✔️Responsive website</li>
                <li>✔️Free SSL + SEO</li>
            </ul>
            <button class="styling">Subscribe now</button>
        </div>


    </section>
</body>
</html>


#Ques. 5 . build a clone of the IRCTC Ticket booking page.

Ans. <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="clonee.css">
</head>
<body>
    <section style="margin: 40px;">
        <div class="clone">
            <img src="https://aonestop.info/wp-content/uploads/2023/03/irctc.webp" alt="logo"> <br>
            <img src="https://5.imimg.com/data5/SELLER/Default/2021/2/GI/JR/US/4184318/irctc-agentship-provider.png" alt="railway">
            <a href="#" class="one">Ask Disha</a>
            <a href="#"class="one">Contact us</a>
            <a href="#"class="one">Alerts</a> <br>
            <a href="#"class="one" id="two">Login</a>
            <a href="#"class="one">Register</a>
             <a href="#"class="one">Agent login</a>
           <div>

            <img style=" height: 250px; width: 300px; display: ; " src="https://www.informalnewz.com/wp-content/webp-express/webp-images/uploads/2024/06/Vande-Bharat-Sleeper-Train-2.jpg.webp" alt="vande bharat">
            <img style="height: 250px; width: 300px; " src="https://www.shutterstock.com/image-photo/northern-island-new-zealand-march-260nw-2527965775.jpg" alt="view">
           </div>
        </div>
         <h2>Indian Railway</h2>
          <div id="three">
            <p style="color: green;"> Safety</p>
            <p style="color: orangered;">Security</p>
            <p style="color: blue;">Punctuality</p>
          </div>
          <div id="four">
           <button style="background-color: rgb(13, 13, 179); color: white;">Book tickets</button>
           <button>PNR status</button>
           <button>Chart vacancy</button>
          </div> <br>
          <div>
            <button class="five">
              <div>
                <p>From</p>
                <h3>Bangalore</h3>
                <p>KSR-Bangalore</p>

              </div>

              <div>
                <p>To</p>
                <h3>Kasaragod</h3>
                <p>KSD-kasaragod</p>
              </div>
            </button>
          </div> <br>
          <button class="four">
           <div>
             <p>Date</p>
            <h3>01 Aug 23</h3>
            <p>Tuesday</p>
           </div>
           <div>
            <p>Class</p>
            <h3>3A</h3>
            <p>Ac 3 tier</p>
           </div>
           <div>
            <p>Seal type</p>
            <h3>TATKAL</h3>
            <p>AC 3 tier</p>
           </div>
          </button> <br><br>
          <button class="seven">Search Train</button>

    </section>
</body>
</html>
