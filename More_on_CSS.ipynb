# %%
#Ques.1    Create a navigation bar similar to the below-mentioned image. The navigation bar must contain 5
navigation links that are properly placed within the navigation bar using the CSS box model. The navigation
items must change their text color on hover.

Answer :   <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Navigation link</title>
    <style>
        nav ul {
            background-color: skyblue;
            color: white;
            list-style: none;
            display: flex;
            gap: 40px;
             border: 2px;
            margin: 20px;
            padding: 30px;


        }
        :hover {
            color: black;

        }
    </style>
</head>
<body>
   <nav>
    <ul>
        <li>
            <a href="#">Home</a>
        </li>
        <li>
            <a href="#">About us</a>
        </li>
        <li>
            <a href="#">Contact</a>
        </li>
        <li>
            <a href="#">Blog</a>
        </li>
        <li>
            <a href="#">login</a>
        </li>
    </ul>
   </nav>

</body>
</html>


#Ques.2    Create a navigation bar similar to question 1. For each navigation item, use a different border style ?

Answer :   <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Navigation link</title>
    <style>
        .one {
            border: 2px;
            border-style: dashed;
            border-color: red;
            margin: 10px;
            padding: 20px;
            width: 30px;
            background-color: skyblue;




        }
        .two{
             border: 2px;
             border-style: dotted;
             border-color: green;
            margin: 10px;
            padding: 20px;
            width: 30px;
            background-color: skyblue;


         }

         .three {
            border: 2px;
            border-style: groove;
            border-color: yellow;
            margin: 10px;
            padding: 20px;
            width: 30px;
            background-color: skyblue;

         }

         .four{
            border: 2px;
            border-style: solid;
            border-color: crimson;
            margin: 10px;
            padding: 20px;
            width: 30px;
            background-color: skyblue;

         }

         .fifth{
            border: 2px;
            border-style: ridge;
            border-color: chocolate;
            margin: 10px;
            padding: 20px;
            width: 30px;
            background-color: skyblue;

         }
        :hover {
            color: blue;

        }
    </style>
</head>
<body>
   <nav>
    <ul style="display: flex; list-style: none; text-align: center; height: 80px;">
        <li class="one">
            <a href="#">Home</a>
        </li>
        <li class="two">
            <a href="#">About us</a>
        </li>
        <li class="three">
            <a href="#">Contact</a>
        </li>
        <li class="four">
            <a href="#">Blog</a>
        </li>
        <li class="fifth">
            <a href="#">login</a>
        </li>
    </ul>
   </nav>

</body>
</html>


#Ques.3   Create a simple list of items as mentioned in the below image.

Answer.   <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Simple list</title>
</head>
<body>
    <div style="border-style: solid;">
        <h1>Requirements</h1>
        <ol style="list-style-type: lower-roman;">
            <li>
                System with minimum i3 processor or better.
            </li>
            <li>
                At least 4 GB of RAM.
            </li>
            <li>
                Working internet connection.
            </li>
            <li>
                Dedication to learn
            </li>
        </ol>
    </div>
</body>
</html>


#Ques.4   Create a simple blog website about Google fonts. The webpage must have the heading with “Oswald” font
align center to the page, below the heading have an image of Google fonts and a paragraph about Google
fonts in font “Montserrat” paragraph font style should be“montserrat” font?

Answer.   <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Simple blog</title>
</head>
<body>
    <div style="font-family: ;">
        <h1 style="text-align: center;"><u>Oswald</u></h1><hr color="black">
        <img style="height: 100px;" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSAT3zQ6PmZac04m4Psa6gpkpZ6INUKaLSeyA&s" alt="goggle fonts">
        <img style="height: 100px;" src="https://ted-ielts.com/wp-content/uploads/2016/11/paragraph-structure.png" alt="paragraph image">
        <p>
           <h2><u>Google fonts:</u></h2>
            <ul>
            <li>Google Fonts is a vast library of free, open-source fonts designed for web use. It offers a wide variety of typefaces, ranging from classic to modern styles, in over 135 languages. These fonts can be easily incorporated into websites and apps using a simple API or traditional CSS methods. </li>
        </ul>

         </p>
         <p>
            <h2><u>paragraph:</u></h2>
            <ul>
                <li>A paragraph is a group of sentences that work together to develop a single idea or point, forming a cohesive unit within a larger piece of writing like an essay or article. It's a building block of coherent communication, helping to organize thoughts and present information in a clear and logical way. </li>
            </ul>
         </p>
    </div>

</body>
</html>


#Ques.5.  Create a simple webpage with an image and make the image circular using border-radius?

Answer.   <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>CSS introduction</title>
</head>
<body>
    <section>
        <h1 style="text-align: center;"><u>CSS</u></h1>
        <p style="font-style: inherit;">Cascading Style Sheets (CSS) is a style sheet language used for specifying the presentation and styling of a document written in a markup language such as HTML or XML (including XML dialects such as SVG, MathML or XHTML). CSS is a cornerstone technology of the World Wide Web, alongside HTML and JavaScript.
        </p>
        <img style="height: 250px; border-radius: 50% ; width: 250px;" src="https://cdn.mos.cms.futurecdn.net/Vp9WvV7YKdH4k8sKRePcE8.jpg" alt="centered">
    </section>
</body>
</html>


#Ques.6   Create a simple website as mentioned in the below image. You can get the assets by visiting https://
pwskills.com/about-us.

Ans. <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PW sills about us</title>
    <style>
        img{
            display: block;
            width: 100%;
            height: auto;
            margin: 20px auto 0;
            border-radius: 10px;
            margin-bottom: 20px;



            }
            h1{
                text-align: center;
            }
            p{
                font-style: normal;
                font-size: 16px;
                line-height: 1.6;
            }
    </style>
</head>
<body>
    <div style="border-style: solid; margin: 20px;">
        <h1>About us</h1>
        <p>
            PW skills' mission os to permeate through every student/professional's outlook toward job and change thier attitude and perspective from "How can I Do it" to "Off Couse I can do it".
            We aim to do this by providing exceptional up skilling course at affordable rates , while being tech-forward so anyone ,anywhere can access and improve their ability to be successful in life.
        </p>
        <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT5QKe2CqCOj8nmJhv_hsCpKd5h7KuoOxHYbg&s" alt="pw skills event image">
    </div>
</body>
</html>


#Ques.7    Create a div centered with an image and paragraph similar to the image mentioned below.

Ans.       <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Full stack devlopment</title>
    <style>



        img{
            width: 50%;
            display: block;


        }
        p{
            font-family: 'Times New Roman', Times, serif;
            line-height: 1.6;
            font-size: 16px;
            font-weight: bold;
            text-align: center;
        }
    </style>
</head>
<body>
    <div>
        <center><img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTBbXrRnX4vCTdBOonoZR2kJBGQmAUnygjzOw&s" alt="full stack devlopment"></center>
        <p>Full stack development is the process of developing both the frontend and backend of applications. Any application has a frontend (user-facing) component and a backend (database and logic) component. The frontend contains the user interface and code related to user interactions with the application.</p>
    </div>

</body>
</html>


#Ques.8    Create a simple webpage with a card similar to question number 2. The card must be semi-transparent as
default and on hovering the card must be displayed clearly. Use CSS opacity to achieve this output.


Ans.       <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        .image{
            width: 50%;
            border: 2px;

            margin: 10px;
            padding: 10px;
            border-radius: 20px;
            background-color: aqua;
        }
        .image2{
            width: 50%;
            border: 2px;

            margin: 10px;
            padding: 10px;
            border-radius: 20px;
            background-color: aqua;

        }
       .image2 :hover {
        opacity: 1S;
       }
    </style>
</head>
<body>
    <h1>Without hover</h1>
    <div style="border-style: solid;">
        <img class="image" src="https://img.youtube.com/vi/ofekyjYd0xM/hqdefault.jpg" alt="full stack">

    </div>
    <h1>With hover</h1>
    <div style="border-style: solid; opacity: 0.5;">
        <img class="image2" src="https://img.youtube.com/vi/ofekyjYd0xM/hqdefault.jpg" alt="full stack">
    </div>

</body>
</html>
