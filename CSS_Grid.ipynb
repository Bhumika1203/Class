# %%
#Ques.1 Explain the difference between justify-items and justify-self using code examples??

Ans. Justify-item : Justify item is work on container means its sets horizontal alignment for all item in a grid.
     Justify-Self : Justify self is work on item only means it sets horizontal alignment for one specific item.

For example - Justify item ---


<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
  .grid {
    display: grid;
    grid-template-columns: repeat(3, 100px);
    justify-items:  center; /* applies to ALL items */
    gap: 10px;
    border: 2px solid black;
    ju
  }

  .item {
    background: lightblue;
    padding: 10px;
  }
</style>
</head>
<body>


<div class="grid">
  <div class="item">Item 1</div>
  <div class="item">Item 2</div>
  <div class="item">Item 3</div>
</div>

</body>
</html>


Example of Justify-self-

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
  .grid {
    display: grid;
    grid-template-columns: repeat(3, 100px);
    justify-self:   center; /* applies to ALL items */
    gap: 10px;
    border: 2px solid black;
    ju
  }

  .item {
    background: lightblue;
    padding: 10px;
  }
</style>
</head>
<body>


<div class="grid">
  <div class="item">Item 1</div>
  <div class="item">Item 2</div>
  <div class="item">Item 3</div>
</div>

</body>
</html>


#Ques.2  Explain the use of grid-auto-row and grid-auto-column using code examples.

Ans.   Grid-auto-row - it Sets the size of rows that are not explicitly defined in grid-template-rows.
       grid-auto-columns: it Sets the size of columns that are not explicitly defined in grid-template-columns.

Example of Grid-auto-column;

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
  .grid {
    display: grid;
    grid-template-rows: repeat(4, 100px);
    grid-auto-columns: 100px;
    justify-content: center;
    gap: 15px;


  }

  .item {
    background: pink;
    padding: 10px;
    border: 1px solid red;
    text-align: center;
  }
</style>
</head>
<body>


<div class="grid">
  <div class="item">box 1</div>
  <div class="item">box 2</div>
  <div class="item">box 3</div>
  <div class="item"> box 4</div>
</div>

</body>
</html>


Example of Grid-auto-row:


<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
  .grid {
    display: grid;
    grid-template-columns: repeat(4, 100px);
    grid-auto-rows: 50px;
    justify-content: center;
    gap: 15px;


  }

  .item {
    background: lightgreen;
    padding: 10px;
    border: 1px solid red;
    text-align: center;
  }
</style>
</head>
<body>


<div class="grid">
  <div class="item">box 1</div>
  <div class="item">box 2</div>
  <div class="item">box 3</div>
  <div class="item"> box 4</div>
</div>

</body>
</html>


#Ques .3 Write code to arrange containers with texts A, B, C, and D as shown in the below image.

Ans. <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        .container {
  display: grid;
  grid-template-columns: 2fr 1fr; /* A is wider than B */
  grid-template-rows: auto auto;
  gap: 10px;
  width: 300px;
  background-color: #eee;
  padding: 10px;
}

.box {
  background-color: peachpuff;
  padding: 20px;
  font-size: 20px;
  text-align: center;

  border-radius: 5px;
}




    </style>
</head>
<body>
    <div class="container">
  <div class="box">A</div>
  <div class="box">B</div>
  <div class="box">C</div>
  <div class="box">D</div>
</div>

</body>
</html>

#Ques.4  Create an image gallery using a CSS grid.


Ans. <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="lab.css">
</head>
<body>
    <div id="gallery">
        <img class="image1" src="https://images.meesho.com/images/products/109220737/xipxj_512.webp" alt="image1">
        <img class="image2" src="https://solo.in/cdn/shop/files/a4-coloured-papers-5-sheets-each-color-copy-printingart-and-craft-paper-double-sided-316696.webp?v=1742021714" alt="image2">
        <img class="image3" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQsTobF_NwxWK_AbWgDoFONFMXAw6wY5ItCsg&s" alt="image3">
        <img class="image4" src="https://p16-oec-va.ibyteimg.com/tos-maliva-i-o3syd03w52-us/c6c527a564784605b534421c1e2180fa~tplv-dx0w9n1ysr-crop-webp:400:400.webp?dr=10517&t=555f072d&ps=933b5bde&shp=57fff0e0&shcp=0d52deaf&idc=useast5&from=1476391136" alt="image4">
        <img class="image5" src="https://static.vecteezy.com/system/resources/thumbnails/004/712/598/small_2x/medical-concept-of-disposable-syringes-of-different-volumes-on-a-blue-background-photo.jpg" alt="image5">
        <img class="image6" src="https://media.istockphoto.com/id/1304499871/photo/medical-disposable-syringe-for-vaccine-injection-and-glass-vial.jpg?s=612x612&w=0&k=20&c=Hyrdv7Iz9dq_RdOiE7htszWa93bkCSpaiOS04lqG2eQ=" alt="image 6">
    </div>
</body>
</html>
